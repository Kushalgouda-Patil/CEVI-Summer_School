# %%
# !pip install numpy matplotlib scikit-image scipy


import numpy as np
import matplotlib.pyplot as plt
from skimage.io import imshow, imread
from skimage.color import rgb2yuv, rgb2hsv, rgb2gray, yuv2rgb, hsv2rgb
from scipy.signal import convolve2d
# Out:
# Requirement already satisfied: numpy in c:\users\kusha\anaconda3\lib\site-packages (1.23.5)
# Requirement already satisfied: matplotlib in c:\users\kusha\anaconda3\lib\site-packages (3.6.2)
# Collecting scikit-image
#   Downloading scikit_image-0.21.0-cp310-cp310-win_amd64.whl (22.8 MB)
#      ---------------------------------------- 22.8/22.8 MB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: scipy in c:\users\kusha\anaconda3\lib\site-packages (1.11.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kusha\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\kusha\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\kusha\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kusha\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kusha\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\kusha\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\kusha\anaconda3\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kusha\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Collecting lazy_loader>=0.2
#   Downloading lazy_loader-0.3-py3-none-any.whl (9.1 kB)
# Collecting networkx>=2.8
#   Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#      ---------------------------------------- 2.1/2.1 MB 3.6 MB/s eta 0:00:00
# Collecting imageio>=2.27
#   Downloading imageio-2.31.3-py3-none-any.whl (313 kB)
#      -------------------------------------- 313.0/313.0 kB 2.8 MB/s eta 0:00:00
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.4.1-cp310-cp310-win_amd64.whl (4.2 MB)
#      ---------------------------------------- 4.2/4.2 MB 2.8 MB/s eta 0:00:00
# Collecting tifffile>=2022.8.12
#   Downloading tifffile-2023.8.30-py3-none-any.whl (221 kB)
#      -------------------------------------- 221.9/221.9 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in c:\users\kusha\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: tifffile, PyWavelets, networkx, lazy_loader, imageio, scikit-image
# Successfully installed PyWavelets-1.4.1 imageio-2.31.3 lazy_loader-0.3 networkx-3.1 scikit-image-0.21.0 tifffile-2023.8.30

# %%
dog = imread('fire_dog.webp',0)
plt.figure(num=None, figsize=(8, 6), dpi=80)
imshow(dog);
print(dog.shape)
# Out:
# (576, 578, 3)

# %%
# Sharpen
sharpen = np.array([[0, -1, 0],
                    [-1, 5, -1],
                    [0, -1, 0]])
# Gaussian Blur
gaussian = (1 / 16.0) * np.array([[1., 2., 1.],
                                  [2., 4., 2.],
                                  [1., 2., 1.]])

print(gaussian.shape)
fig, ax = plt.subplots(1,2, figsize = (17,10))
ax[0].imshow(sharpen, cmap='gray')
ax[0].set_title(f'Sharpen', fontsize = 18)
    
ax[1].imshow(gaussian, cmap='gray')
ax[1].set_title(f'Gaussian Blur', fontsize = 18)
    
[axi.set_axis_off() for axi in ax.ravel()];
# Out:
# (3, 3)

# %%
dog_grey = rgb2gray(dog)
plt.figure(num=None, figsize=(8, 6), dpi=80)
imshow(dog_grey);

# %%
convolved_image = multi_convolver(dog_grey, gaussian, 2)
plt.figure(num=None, figsize=(8, 6), dpi=80)
imshow(convolved_image);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 convolved_image = multi_convolver(dog_grey, gaussian, 2)
#       2 plt.figure(num=None, figsize=(8, 6), dpi=80)
#       3 imshow(convolved_image)
#
# NameError: name 'multi_convolver' is not defined

# %%
def convolution_plotter(image, kernel):
    iterations = [1,10,20,30]
    f_size = 20
    
    fig, ax = plt.subplots(1,4, figsize = (15,7))
    for n, ax in enumerate(ax.flatten()):
        ax.set_title(f'Iteration : {iterations[n]}', fontsize =
                     f_size)
        ax.imshow(multi_convolver(image, kernel, iterations[n]), 
                  cmap='gray')
        ax.set_axis_off()
    fig.tight_layout()
    
convolution_plotter(dog_grey, gaussian)
