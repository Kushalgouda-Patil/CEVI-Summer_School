# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
img1=cv2.imread("..\images\coco.png")
img2=cv2.imread("..\images\check_c.png")

# %%
img1=img1[:,:,::-1]
img2=img2[:,:,::-1]
plt.imshow(img1)
#plt.imshow(img2)

# %%
img1
# Out:
# array([[[199,   4,  21],
#         [199,   4,  21],
#         [199,   4,  21],
#         ...,
#         [199,   4,  21],
#         [199,   4,  21],
#         [199,   4,  21]],
#
#        [[199,   4,  21],
#         [199,   4,  21],
#         [199,   4,  21],
#         ...,
#         [199,   4,  21],
#         [199,   4,  21],
#         [199,   4,  21]],
#
#        [[199,   4,  21],
#         [199,   4,  21],
#         [199,   4,  21],
#         ...,
#         [199,   4,  21],
#         [199,   4,  21],
#         [199,   4,  21]],
#
#        ...,
#
#        [[199,   4,  21],
#         [199,   4,  21],
#         [199,   4,  21],
#         ...,
#         [199,   4,  21],
#         [199,   4,  21],
#         [199,   4,  21]],
#
#        [[199,   4,  21],
#         [199,   4,  21],
#         [199,   4,  21],
#         ...,
#         [199,   4,  21],
#         [199,   4,  21],
#         [199,   4,  21]],
#
#        [[199,   4,  21],
#         [199,   4,  21],
#         [199,   4,  21],
# ...

# %%
img1=cv2.cvtColor(img1,cv2.COLOR_RGB2GRAY )
plt.imshow(img1,cmap='gray')

# %%
retval, img1=cv2.threshold(img1, 127, 255, cv2.THRESH_BINARY)
plt.imshow(img1,cmap='gray')

# %%
img1=cv2.cvtColor(img1,cv2.COLOR_GRAY2RGB )
plt.imshow(img1)

# %%
result = cv2.bitwise_and(img1, resized_cropped_region, mask=None)
plt.imshow(result)

# %%
img2[0:700,0:700,:].shape
# Out:
# (700, 700, 3)

# %%
resized_cropped_region = cv2.resize(img2, dsize=img1.shape[0:2], interpolation=cv2.INTER_AREA)
plt.imshow(resized_cropped_region)

# %%
img_mask_inv = cv2.bitwise_not(img1)
plt.imshow(img_mask_inv)

# %%
result2 = cv2.bitwise_or(img_mask_inv, resized_cropped_region, mask=None)
plt.imshow(result2)

# %%
result3 = cv2.bitwise_and(cv2.imread("..\images\coco.png")[:,:,::-1], result2, mask=None)
plt.imshow(result3)

# %%
img_background = cv2.bitwise_and(jkl, jkl,mask=result2)
plt.imshow(img_background)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[81], line 1
# ----> 1 img_background = cv2.bitwise_and(jkl, jkl,mask=result2 )
#       2 plt.imshow(img_background)
#
# error: OpenCV(4.8.0) D:\a\opencv-python\opencv-python\opencv\modules\core\src\arithm.cpp:230: error: (-215:Assertion failed) (mtype == CV_8U || mtype == CV_8S) && _mask.sameSize(*psrc1) in function 'cv::binary_op'

# %%
jkl=cv2.imread("..\images\coco.png")[:,:,::-1]
plt.imshow(jkl)
